# %% [markdown]
# <a href="https://colab.research.google.com/github/karthickx96-beep/os-project/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# if else

# %%
mark=int(input("Enter student mark"))
if(mark>35):
  print("pass")
else:
  print("fail")
# Out:
# Enter student mark33
# fail

# %%
income=int(input("Enter your income "))
if(income>7000):
  print ("scholarship is available")
else:
  print("scholarship is not avaliable")
# Out:
# Enter your income 9000
# scholarship is available

# %%
number=int(input())
if(number%2==0):
  print("even")
else:
  print("odd")
# Out:
# 87
# odd

# %%
mark=int(input())
if(mark<35):
  print("poor")
elif(mark>35 and mark<70):
  print("avg")
else:
  print("good")
# Out:
# 87
# good

# %%
a=int(input())
b=int(input())
add=a+b
sub=a-b
mul=a*b
div=a/b
operation=input("enter ")
if(operation=="add"):
  print(add)
elif(operation=="sub"):
  print(sub)
elif(operation=="mul"):
  print(mul)
else:
  print("div")
# Out:
# 9
# 7
# enter mul
# 63
